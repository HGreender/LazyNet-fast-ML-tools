# %%
from fast_ml_tools.ml.utils.json_to_mask import process_json_to_mask


BASE_DIR = 'dir_path/'
process_json_to_mask(
    json_path = BASE_DIR + 'annotations/Train.json', # CVAT annotations
    originals_dir = BASE_DIR + 'images/',
    output_dir = BASE_DIR + 'masks/',
    label_id = 12,
    with_postfix = False # If True, save masks as 'image_name_mask.png'
)
