# %%
from fast_ml_tools import LazyNet


model = LazyNet(
    model_name = 'efficientnetb4_unet',
    train_img_dir = r'./train/orig',
    train_mask_dir = r'./train/masks',
    val_img_dir = r'./val/orig',
    val_mask_dir = r'./val/masks',
    epochs = 2,
    batch_size = 10,
    lr = 1e-4,
    patience = 5,
    verbose = True, 
    device_id = 0, 
    num_workers = 0,
    classes = ['target_class']
)
model.fit(save_model_path='./test/test.pth', save_logs_path='./test/test.json')
model.draw_logs()
